# %%
import pandas as pd

# %%
df = pd.read_excel("./../data/text_labels.xlsx", sheet_name=0)

# %%
df.head()
# Out:
#                                         file  cogn_func  is_cogn_func_basic  \
# 0        0000_000_999-accidentes-trabajo.txt          6                   0
# 1            012015-Lecciones-aprendidas.txt          7                   0
# 2      31-5_Caida_desde_escalera_de_silo.txt          3                   0
# 3  auxiliar_trafico_aprisionado_vehiculo.txt          5                   0
# 4                          caida_alturas.txt          3                   0
#
#    emotion  is_emotion_basic  cogn_test  cogn_test_is_groupal  \
# 0        6                 0          5                     0
# 1        4                 1          3                     1
# 2        6                 0          4                     0
# 3        9                 0          5                     1
# 4        0                 1          2                     0
#
#    cogn_test_is_oral  characteristic  behaviour  capability  comp_activity  \
# ...

# %%
text_files = df.file

documents = []
for text_file in text_files:
    with open(f"./../data/text/prep/{text_file}", "r") as f:
        documents.append("".join(f.readlines()))

# %% [markdown]
# ## TF-IDF Representation

# %%
## Remove stop words

import spacy
 
# Load spaCy spanish model
nlp = spacy.load("es_core_news_sm")
 
clean_docs = []

for text in documents:

 
# Process the text using spaCy
    doc = nlp(text)
    
    # Remove stopwords
    filtered_words = [token.text for token in doc if not token.is_stop]
 
# Join the filtered words to form a clean text
    clean_text = ' '.join(filtered_words)
    clean_docs.append(clean_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(clean_docs)

# %%
X = tfidf.toarray()
X = pd.DataFrame(X)
X
# Out:
#         0         1         2         3         4         5         6     \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ..       ...       ...       ...       ...       ...       ...       ...
# 79  0.004120  0.000000  0.009899  0.000000  0.000000  0.009899  0.000000
# 80  0.000000  0.011850  0.000000  0.000000  0.015638  0.000000  0.000000
# 81  0.037983  0.113985  0.000000  0.000000  0.000000  0.000000  0.038390
# 82  0.000000  0.066779  0.000000  0.017962  0.000000  0.000000  0.014459
# 83  0.000000  0.011817  0.000000  0.000000  0.000000  0.000000  0.000000
#
#        7     8         9     ...  9887      9888  9889  9890  9891  9892  \
# ...

# %%
X.shape
# Out:
# torch.Size([84, 9897])

# %%
y = df.dropna(axis=1)
y = y.drop("file", axis=1)
y
# Out:
#     cogn_func  is_cogn_func_basic  emotion  is_emotion_basic  cogn_test  \
# 0           6                   0        6                 0          5
# 1           7                   0        4                 1          3
# 2           3                   0        6                 0          4
# 3           5                   0        9                 0          5
# 4           3                   0        0                 1          2
# ..        ...                 ...      ...               ...        ...
# 79          6                   0        7                 0          0
# 80          5                   0        0                 1          5
# 81          5                   0        9                 0          5
# 82          1                   1        6                 0          0
# 83          5                   0        2                 1          4
#
#     cogn_test_is_groupal  cogn_test_is_oral  capability  level  mechanic  \
# ...

# %%
y.shape
# Out:
# (84, 13)

# %%
y.to_csv("./../data/features/out_features.csv", index=False)
X.to_csv("./../data/features/in_features.csv", index=False)
